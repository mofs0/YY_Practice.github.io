# %%
#获取数据
#数据处理:缺失值
#数据集划分
#特征工程 无量纲化
#逻辑回归预估器
#模型评估

# %%
import pandas as pd
import numpy as np

# %%
breast = pd.read_csv('breast-cancer-wisconsin.data')
breast
# Out:
#      1000025  5   1  1.1  1.2  2 1.3   3  1.4  1.5  2.1
# 0    1002945  5   4    4    5  7  10   3    2    1    2
# 1    1015425  3   1    1    1  2   2   3    1    1    2
# 2    1016277  6   8    8    1  3   4   3    7    1    2
# 3    1017023  4   1    1    3  2   1   3    1    1    2
# 4    1017122  8  10   10    8  7  10   9    7    1    4
# ..       ... ..  ..  ...  ... ..  ..  ..  ...  ...  ...
# 693   776715  3   1    1    1  3   2   1    1    1    2
# 694   841769  2   1    1    1  2   1   1    1    1    2
# 695   888820  5  10   10    3  7   3   8   10    2    4
# 696   897471  4   8    6    4  3   4  10    6    1    4
# 697   897471  4   8    8    5  4   5  10    4    1    4
#
# [698 rows x 11 columns]

# %%
#数据处理:缺失值
breast = breast.replace(to_replace='?',value=np.nan)
breast.head(50)
# Out:
#     1000025   5   1  1.1  1.2   2  1.3  3  1.4  1.5  2.1
# 0   1002945   5   4    4    5   7   10  3    2    1    2
# 1   1015425   3   1    1    1   2    2  3    1    1    2
# 2   1016277   6   8    8    1   3    4  3    7    1    2
# 3   1017023   4   1    1    3   2    1  3    1    1    2
# 4   1017122   8  10   10    8   7   10  9    7    1    4
# 5   1018099   1   1    1    1   2   10  3    1    1    2
# 6   1018561   2   1    2    1   2    1  3    1    1    2
# 7   1033078   2   1    1    1   2    1  1    1    5    2
# 8   1033078   4   2    1    1   2    1  2    1    1    2
# 9   1035283   1   1    1    1   1    1  3    1    1    2
# 10  1036172   2   1    1    1   2    1  2    1    1    2
# 11  1041801   5   3    3    3   2    3  4    4    1    4
# 12  1043999   1   1    1    1   2    3  3    1    1    2
# 13  1044572   8   7    5   10   7    9  5    5    4    4
# 14  1047630   7   4    6    4   6    1  4    3    1    4
# 15  1048672   4   1    1    1   2    1  2    1    1    2
# 16  1049815   4   1    1    1   2    1  3    1    1    2
# 17  1050670  10   7    7    6   4   10  4    1    2    4
# 18  1050718   6   1    1    1   2    1  3    1    1    2
# 19  1054590   7   3    2   10   5   10  5    4    4    4
# 20  1054593  10   5    5    3   6    7  7   10    1    4
# 21  1056784   3   1    1    1   2    1  2    1    1    2
# 22  1057013   8   4    5    1   2  NaN  7    3    1    4
# 23  1059552   1   1    1    1   2    1  3    1    1    2
# 24  1065726   5   2    3    4   2    7  3    6    1    4
# 25  1066373   3   2    1    1   1    1  2    1    1    2
# 26  1066979   5   1    1    1   2    1  2    1    1    2
# 27  1067444   2   1    1    1   2    1  2    1    1    2
# 28  1070935   1   1    3    1   2    1  1    1    1    2
# 29  1070935   3   1    1    1   1    1  2    1    1    2
# 30  1071760   2   1    1    1   2    1  3    1    1    2
# 31  1072179  10   7    7    3   8    5  7    4    3    4
# 32  1074610   2   1    1    2   2    1  3    1    1    2
# 33  1075123   3   1    2    1   2    1  2    1    1    2
# 34  1079304   2   1    1    1   2    1  2    1    1    2
# 35  1080185  10  10   10    8   6    1  8    9    1    4
# 36  1081791   6   2    1    1   1    1  7    1    1    2
# 37  1084584   5   4    4    9   2   10  5    6    1    4
# 38  1091262   2   5    3    3   6    7  7    5    1    4
# 39  1096800   6   6    6    9   6  NaN  7    8    1    2
# 40  1099510  10   4    3    1   3    3  6    5    2    4
# 41  1100524   6  10   10    2   8   10  7    3    3    4
# 42  1102573   5   6    5    6  10    1  3    1    1    4
# 43  1103608  10  10   10    4   8    1  8   10    1    4
# 44  1103722   1   1    1    1   2    1  2    1    2    2
# 45  1105257   3   7    7    4   4    9  4    8    1    4
# 46  1105524   1   1    1    1   2    1  2    1    1    2
# 47  1106095   4   1    1    3   2    1  3    1    1    2
# 48  1106829   7   8    7    2   4    8  3    8    2    4
# 49  1108370   9   5    8    1   2    3  2    1    5    4

# %%
breast = breast.dropna()
breast.isnull().any()
# Out:
# 1000025    False
# 5          False
# 1          False
# 1.1        False
# 1.2        False
# 2          False
# 1.3        False
# 3          False
# 1.4        False
# 1.5        False
# 2.1        False
# dtype: bool

# %%
#划分数据集
from sklearn.model_selection import train_test_split

# %%
#筛选特征值和目标值
x=breast.iloc[:,1:-1]
y=breast['2.1']
# Out:
#      5   1  1.1  1.2  2 1.3   3  1.4  1.5
# 0    5   4    4    5  7  10   3    2    1
# 1    3   1    1    1  2   2   3    1    1
# 2    6   8    8    1  3   4   3    7    1
# 3    4   1    1    3  2   1   3    1    1
# 4    8  10   10    8  7  10   9    7    1
# ..  ..  ..  ...  ... ..  ..  ..  ...  ...
# 693  3   1    1    1  3   2   1    1    1
# 694  2   1    1    1  2   1   1    1    1
# 695  5  10   10    3  7   3   8   10    2
# 696  4   8    6    4  3   4  10    6    1
# 697  4   8    8    5  4   5  10    4    1
#
# [682 rows x 9 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
#标准化
from sklearn.preprocessing import StandardScaler

# %%
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
estimator = LogisticRegression()
estimator.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#逻辑回归的模型参数:回归系数和偏置
estimator.coef_
# Out:
# array([[1.31924836, 0.38660061, 0.7735281 , 0.8608061 , 0.31029448,
#         1.18210302, 0.7609156 , 0.44558492, 0.60394906]])

# %%
estimator.intercept_
# Out:
# array([-1.22118112])

# %%
#模型评估
#方法一：直接比对真实值预测值
y_predict = estimator.predict(x_test)
print('y_predict: \n',y_predict)
print('直接比对真实值和预测值: \n',y_test == y_predict)
#方法二:计算准确率
score = estimator.score(x_test,y_test)
print('准确率: \n',score)
# Out:
# y_predict:
#  [2 4 2 2 2 4 4 2 4 4 2 2 4 2 2 4 2 2 2 2 2 2 2 2 4 2 2 2 2 2 2 4 2 2 2 2 2
#  4 4 2 2 2 4 2 4 2 2 2 2 2 4 2 2 2 2 4 4 2 4 2 4 4 2 2 4 2 4 2 4 4 4 2 2 2
#  4 4 4 4 2 2 2 4 2 2 2 2 2 2 2 4 4 2 2 2 2 4 2 2 4 2 4 2 2 4 4 2 2 4 4 2 2
#  4 2 4 4 2 4 4 2 2 2 2 4 4 4 4 2 2 2 4 2 4 4 4 2 2 2 2 4 4 2 4 2 4 2 2 2 2
#  2 2 2 2 2 2 2 4 4 2 4 4 2 4 4 2 4 2 4 2 2 2 2]
# 直接比对真实值和预测值:
#  191     True
# 58      True
# 152     True
# 401     True
# 323     True
#        ...
# 433    False
# 662     True
# 674     True
# 520     True
# 129     True
# Name: 2.1, Length: 171, dtype: bool
# 准确率:
#  0.9824561403508771

# %%
#精确率，召回率，F1-score
from sklearn.metrics import classification_report

# %%
report = classification_report(y_test,y_predict,labels=[2,4],target_names=['良性','恶性'])

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           良性       0.98      0.99      0.99       107
#           恶性       0.98      0.97      0.98        64
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171
