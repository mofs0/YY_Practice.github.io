# %% [markdown]
# # Pandas进阶修炼120题

# %% [markdown]
# ## 第一期 Pandas基础

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1.将下面的字典创建为DataFrame

# %%
data = {
    "grammer": ["Python", "C", "Java", "GO", np.nan, "SQL", "PHP", "Python"],
    "score": [1, 2, np.nan, 4, 5, 6, 7, 10]
}

# %%
df = pd.DataFrame(data = data)
df
# Out:
#   grammer  score
# 0  Python    1.0
# 1       C    2.0
# 2    Java    NaN
# 3      GO    4.0
# 4     NaN    5.0
# 5     SQL    6.0
# 6     PHP    7.0
# 7  Python   10.0

# %% [markdown]
# ### 2.提取含有字符串"Python"的行

# %%
df[df['grammer'] == 'Python']
# Out:
#   grammer  score
# 0  Python    1.0
# 7  Python   10.0

# %% [markdown]
# ### 3.输出df的所有列名

# %%
df.columns
# Out:
# Index(['grammer', 'score'], dtype='object')

# %% [markdown]
# ### 4.修改第二列列名为'popularity'

# %%
df.rename(columns = {'score':'popularity'},inplace = True)
df
# Out:
#   grammer  popularity
# 0  Python         1.0
# 1       C         2.0
# 2    Java         NaN
# 3      GO         4.0
# 4     NaN         5.0
# 5     SQL         6.0
# 6     PHP         7.0
# 7  Python        10.0

# %% [markdown]
# ### 5.统计grammer列中每种编程语言出现的次数

# %%
df.grammer.value_counts()
# Out:
# Python    2
# C         1
# Java      1
# GO        1
# SQL       1
# PHP       1
# Name: grammer, dtype: int64

# %% [markdown]
# ### 6.将空值用上下值的平均值填充

# %% [markdown]
# #### 通常方法（直接写逻辑，并分别使用df.at,df.loc,df.iloc 完成赋值操作）
#
# 这是语言模型输出的结果，但是仍有值得学习的地方。
#
# 限制：
#
#     首先需要限定范围，要填充的值不能是第一个和最后一个，也可单独写规则，此处不再赘述
#
#     此代码只考虑了空值的上下值都为非空的情况

# %%
# 分别使用df.at,df.loc,df.iloc 完成空值填充
df1 = df[:].copy()

# Find null values
null_values = df1['popularity'].isnull() # 结果为series 非空为False,空值为True

# Iterate over null values and fill with average
for i in range(1, len(df1) - 1): # 因为是使用上下值填充，需要限定范围
    if null_values[i]: # null_values[i]为true时表示空值，需要填充
        # Calculate average of values above and below
        avg = (df1.at[i-1, 'popularity'] + df1.at[i+1, 'popularity']) / 2
        
        # Replace null value with average
        df1.at[i, 'popularity'] = avg

print(df1)
# Out:
#   grammer  popularity
# 0  Python         1.0
# 1       C         2.0
# 2    Java         3.0
# 3      GO         4.0
# 4     NaN         5.0
# 5     SQL         6.0
# 6     PHP         7.0
# 7  Python        10.0

# %%
# Example DataFrame
df1 = df[:].copy()

# Find null values
null_values = df1['popularity'].isnull() # 结果为series 非空为False,空值为True

# Iterate over null values and fill with average
for i in range(1, len(df1) - 1): # 因为是使用上下值填充，需要限定范围
    if null_values[i]: # null_values[i]为true时表示空值，需要填充
        # Calculate average of values above and below
        avg = (df1.loc[i-1, 'popularity'] + df1.loc[i+1, 'popularity']) / 2
        
        # Replace null value with average
        df1.loc[i, 'popularity'] = avg

print(df1)
# Out:
#   grammer  popularity
# 0  Python         1.0
# 1       C         2.0
# 2    Java         3.0
# 3      GO         4.0
# 4     NaN         5.0
# 5     SQL         6.0
# 6     PHP         7.0
# 7  Python        10.0

# %%
# Example DataFrame
df1 = df[:].copy()

# Find null values
null_values = df1['popularity'].isnull() # 结果为series 非空为False,空值为True

# Iterate over null values and fill with average
for i in range(1, len(df1) - 1): # 因为是使用上下值填充，需要限定范围
    if null_values[i]: # null_values[i]为true时表示空值，需要填充
        # Calculate average of values above and below
        avg = (df1.iloc[i-1, 1] + df1.iloc[i+1, 1]) / 2
        
        # Replace null value with average
        df1.iloc[i, 1] = avg

print(df1)
# Out:
#   grammer  popularity
# 0  Python         1.0
# 1       C         2.0
# 2    Java         3.0
# 3      GO         4.0
# 4     NaN         5.0
# 5     SQL         6.0
# 6     PHP         7.0
# 7  Python        10.0

# %% [markdown]
# #### 简便方法（interpolate()）

# %%
df['popularity'] = df['popularity'].fillna(df['popularity'].interpolate())
df
# Out:
#   grammer  popularity
# 0  Python         1.0
# 1       C         2.0
# 2    Java         3.0
# 3      GO         4.0
# 4     NaN         5.0
# 5     SQL         6.0
# 6     PHP         7.0
# 7  Python        10.0

# %% [markdown]
# #### 拓展：df.at,df.loc,df.iloc 介绍与使用区别

# %% [markdown]
# df.at: df.at 主要用于在 DataFrame 中以整数位置的方式访问数据。它接受一个整数索引作为参数，并返回该索引处的单个值。
#
# 请注意，使用 df.at 可能会导致越界访问，因为它不检查索引是否超出了数据集的范围。
#
# 此外.ix索引器在最近的pandas版本中已被弃用，不再推荐使用。
#
# 示例：

# %%
t_data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}

t_df = pd.DataFrame(t_data)

# 使用 df.at() 以整数位置访问数据

print(t_df.at[0,'A']) # 输出：1

print(t_df.at[2,'B']) # 输出：6
# Out:
# 1
# 6

# %% [markdown]
# df.loc: df.loc 是 Pandas DataFrame 中用于基于标签(label)访问数据的函数。它允许您通过行标签和列标签来选择数据。
#
# 与 df.at 不同，df.loc 在访问数据时会抛出异常，如果索引超出了数据集的范围。
#
# 示例：

# %%
t_data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}

t_df = pd.DataFrame(t_data)

# 使用 df.at() 以整数位置访问数据

print(t_df.loc[0,'A']) # 输出：1

print(t_df.loc[2,'B']) # 输出：6
# Out:
# 1
# 6

# %% [markdown]
# df.iloc: df.iloc 也是 Pandas DataFrame 中用于基于整数位置访问数据的函数。它允许您通过整数索引来选择数据。
#
# 与 df.at 类似，使用 df.iloc 也可能导致越界访问。然而，与 df.loc 不同，df.iloc 在访问数据时不会抛出异常。
#
# 示例：

# %%
t_data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}

t_df = pd.DataFrame(t_data)

# 使用 df.at() 以整数位置访问数据

print(t_df.iloc[0,0]) # 输出：1

print(t_df.iloc[2,1]) # 输出：6
# Out:
# 1
# 6

# %% [markdown]
# ### 7.提取popularity列中值大于3的行

# %%
df[df['popularity']>3]
# Out:
#   grammer  popularity
# 3      GO         4.0
# 4     NaN         5.0
# 5     SQL         6.0
# 6     PHP         7.0
# 7  Python        10.0

# %% [markdown]
# ### 8.按照grammer列进行去除重复值

# %%
df.drop_duplicates(subset = ['grammer'])
# Out:
#   grammer  popularity
# 0  Python         1.0
# 1       C         2.0
# 2    Java         3.0
# 3      GO         4.0
# 4     NaN         5.0
# 5     SQL         6.0
# 6     PHP         7.0

# %% [markdown]
# ### 9.计算popularity列平均值

# %%
df['popularity'].mean()
# Out:
# 4.75

# %% [markdown]
# ### 10.将grammer列转换为list

# %%
df['grammer'].values
# Out:
# array(['Python', 'C', 'Java', 'GO', nan, 'SQL', 'PHP', 'Python'],
#       dtype=object)

# %% [markdown]
# ### 11.将DataFrame保存为Excel

# %%
df.to_excel('语法及流行度.xlsx',index = False)

# %% [markdown]
# ### 12.查看数据行列数

# %%
df.shape
# Out:
# (8, 2)

# %% [markdown]
# ### 13.提取popularity列值大于3小于7的行

# %%
df[(df['popularity']>3) & (df['popularity']<7)]
# Out:
#   grammer  popularity
# 3      GO         4.0
# 4     NaN         5.0
# 5     SQL         6.0

# %% [markdown]
# ### 14.交换两列位置

# %%
'''
方法1
'''
temp = df['popularity']
df.drop(labels=['popularity'], axis=1, inplace=True)
df.insert(0, 'popularity', temp)
df
'''
方法2
cols = df.columns[[1,0]]
df = df[cols]
df
'''

# %% [markdown]
# #### 方法一：使用temp做中转

# %%
temp = df['popularity']
df.drop(labels = ['popularity'],axis = 1,inplace = True)
df.insert(0,'popularity',temp)
df
# Out:
#    popularity grammer
# 0         1.0  Python
# 1         2.0       C
# 2         3.0    Java
# 3         4.0      GO
# 4         5.0     NaN
# 5         6.0     SQL
# 6         7.0     PHP
# 7        10.0  Python

# %% [markdown]
# #### 方法二：直接根据columns名称生成新的df

# %%
cols = df.columns[[1,0]]# df.columns[[1,0]] --> Index(['grammer', 'popularity'], dtype='object')
df = df[cols]
df
# Out:
#   grammer  popularity
# 0  Python         1.0
# 1       C         2.0
# 2    Java         3.0
# 3      GO         4.0
# 4     NaN         5.0
# 5     SQL         6.0
# 6     PHP         7.0
# 7  Python        10.0

# %% [markdown]
# ### 15.提取popularity列最大值所在行

# %%
df[df['popularity'] == df['popularity'].max()].index.values[0]
# Out:
# 7

# %% [markdown]
# ### 16.查看最后5行数据

# %%
df.tail()
# Out:
#   grammer  popularity
# 3      GO         4.0
# 4     NaN         5.0
# 5     SQL         6.0
# 6     PHP         7.0
# 7  Python        10.0

# %% [markdown]
# ### 17.删除最后一行数据

# %% [markdown]
# ### 18.添加一行数据['Perl',6.6]

# %% [markdown]
# ### 19.对数据按照"popularity"列值的大小进行排序

# %% [markdown]
# ### 20.统计grammer列每个字符串的长度

# %% [markdown]
# ## 第二期 Pandas数据处理

# %% [markdown]
# ### 21.读取本地EXCEL数据

# %%
import pandas as pd
df = pd.read_excel('pandas120_21_50.xlsx')

# %% [markdown]
# ### 22.查看df数据前5行

# %% [markdown]
# ### 23.将salary列数据转换为最大值与最小值的平均值

# %% [markdown]
# ### 24.将数据根据学历进行分组并计算平均薪资

# %% [markdown]
# ### 25.将createTime列时间转换为月-日

# %% [markdown]
# ### 26.查看索引、数据类型和内存信息

# %% [markdown]
# ### 27.查看数值型列的汇总统计

# %% [markdown]
# ### 28.新增一列根据salary将数据分为三组

# %% [markdown]
# ### 29.按照salary列对数据降序排列

# %% [markdown]
# ### 30.取出第33行数据

# %% [markdown]
# ### 31.计算salary列的中位数

# %% [markdown]
# ### 32.绘制薪资水平频率分布直方图

# %% [markdown]
# ### 33.绘制薪资水平密度曲线

# %% [markdown]
# ### 34.删除最后一列categories

# %% [markdown]
# ### 35.将df的第一列与第二列合并为新的一列

# %% [markdown]
# ### 36.将education列与salary列合并为新的一列

# %% [markdown]
# ### 37.计算salary最大值与最小值之差

# %% [markdown]
# ### 38.将第一行与最后一行拼接

# %% [markdown]
# ### 39.将第8行数据添加至末尾

# %% [markdown]
# ### 40.查看每列的数据类型

# %% [markdown]
# ### 41.将createTime列设置为索引

# %% [markdown]
# ### 42.生成一个和df长度相同的随机数DataFrame

# %% [markdown]
# ### 43.将上一题生成的DataFrame与df合并

# %% [markdown]
# ### 44.生成新的一列new为salary列减去之前生成随机数列

# %% [markdown]
# ### 45.检查数据中是否含有任何缺失值

# %% [markdown]
# ### 46.将salary列类型转换为浮点数

# %% [markdown]
# ### 47.计算salary大于10000的次数

# %% [markdown]
# ### 48.查看每种学历出现的次数

# %% [markdown]
# ### 49.查看education列共有几种学历

# %% [markdown]
# ### 50.提取salary与new列的和大于60000的最后3行

# %% [markdown]
# ## 第三期 金融数据处理

# %% [markdown]
# ### 51.使用绝对路径读取本地Excel数据

# %% [markdown]
# ### 52.查看数据前三行

# %% [markdown]
# ### 53.查看每列数据缺失值情况

# %% [markdown]
# ### 54.提取日期列含有空值的行

# %% [markdown]
# ### 55.输出每列缺失值具体行数

# %% [markdown]
# ### 56.删除所有存在缺失值的行

# %% [markdown]
# ### 57.绘制收盘价的折线图

# %% [markdown]
# ### 58.同时绘制开盘价与收盘价

# %% [markdown]
# ### 59.绘制涨跌幅的直方图

# %% [markdown]
# ### 60.让直方图更细致

# %% [markdown]
# ### 61.以data的列名创建一个DataFrame

# %% [markdown]
# ### 62.打印所有换手率不是数字的行

# %% [markdown]
# ### 63.打印所有换手率为--的行

# %% [markdown]
# ### 64.重置data的行号

# %% [markdown]
# ### 65.删除所有换手率为非数字的行

# %% [markdown]
# ### 66.绘制换手率的密度曲线

# %% [markdown]
# ### 67.计算前一天与后一天收盘价的差值

# %% [markdown]
# ### 68.计算前一天与后一天收盘价变化率

# %% [markdown]
# ### 69.设置日期为索引

# %% [markdown]
# ### 70.以5个数据作为一个数据滑动窗口，在这个5个数据上取均值(收盘价)

# %% [markdown]
# ### 71.以5个数据作为一个数据滑动窗口，计算这五个数据总和(收盘价)

# %% [markdown]
# ### 72.将收盘价5日均线、20日均线与原始数据绘制在同一个图上

# %% [markdown]
# ### 73.按周为采样规则，取一周收盘价最大值

# %% [markdown]
# ### 74.绘制重采样数据与原始数据

# %% [markdown]
# ### 75.将数据往后移动5天

# %% [markdown]
# ### 76.将数据向前移动5天

# %% [markdown]
# ### 77.使用expending函数计算开盘价的移动窗口均值

# %% [markdown]
# ### 78.绘制上一题的移动均值与原始数据折线图

# %% [markdown]
# ### 79.计算布林指标

# %% [markdown]
# ### 80.计算布林线并绘制

# %% [markdown]
# ## 第四期 当Pandas遇上NumPy

# %% [markdown]
# ### 81.导入并查看pandas与numpy版本

# %% [markdown]
# ### 82.从NumPy数组创建DataFrame

# %%
# 备注：使用numpy生成20个0-100随机数

# %% [markdown]
# ### 83.从NumPy数组创建DataFrame

# %%
# 备注：使用numpy生成20个0-100固定步长的数

# %% [markdown]
# ### 84.从NumPy数组创建DataFrame

# %%
# 备注：使用numpy生成20个指定分布(如标准正态分布)的数

# %% [markdown]
# ### 85.将df1，df2，df3按照行合并为新DataFrame

# %% [markdown]
# ### 86.将df1，df2，df3按照列合并为新DataFrame

# %% [markdown]
# ### 87.查看df所有数据的最小值、25%分位数、中位数、75%分位数、最大值

# %% [markdown]
# ### 88.修改列名为col1,col2,col3

# %% [markdown]
# ### 89.提取第一列中不在第二列出现的数字

# %% [markdown]
# ### 90.提取第一列和第二列出现频率最高的三个数字

# %% [markdown]
# ### 91.提取第一列中可以整除5的数字位置

# %% [markdown]
# ### 92.计算第一列数字前一个与后一个的差值

# %% [markdown]
# ### 93.将col1,col2,clo3三列顺序颠倒

# %% [markdown]
# ### 94.提取第一列位置在1,10,15的数字

# %% [markdown]
# ### 95.查找第一列的局部最大值位置

# %%
# 备注：即比它前一个与后一个数字的都大的数字

# %% [markdown]
# ### 96.按行计算df的每一行均值

# %% [markdown]
# ### 97.对第二列计算移动平均值

# %%
# 备注：每次移动三个位置，不可以使用自定义函数

# %% [markdown]
# ### 98.将数据按照第三列值的大小升序排列

# %% [markdown]
# ### 99.将第一列大于50的数字修改为'高'

# %% [markdown]
# ### 100.计算第二列与第三列之间的欧式距离

# %% [markdown]
# ## 第五期 一些补充

# %% [markdown]
# ### 101.从CSV文件中读取指定数据

# %%
# 备注：从数据1中的前10行中读取positionName, salary两列

# %% [markdown]
# ### 102.从CSV文件中读取指定数据

# %%
# 备注：从数据2中读取数据并在读取数据时将薪资大于10000的为改为高

# %% [markdown]
# ### 103.从上一题数据中，对薪资水平列每隔20行进行一次抽样

# %% [markdown]
# ### 104.将数据取消使用科学计数法

# %% [markdown]
# ### 105.将上一题的数据转换为百分数

# %% [markdown]
# ### 106.查找上一题数据中第3大值的行号

# %% [markdown]
# ### 107.反转df的行

# %% [markdown]
# ### 108.按照多列对数据进行合并

# %%
# 输入
df1 = pd.DataFrame({
    'key1': ['K0', 'K0', 'K1', 'K2'],
    'key2': ['K0', 'K1', 'K0', 'K1'],
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3']
})

df2 = pd.DataFrame({
    'key1': ['K0', 'K1', 'K1', 'K2'],
    'key2': ['K0', 'K0', 'K0', 'K0'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
})

# %% [markdown]
# ### 109.按照多列对数据进行合并

# %% [markdown]
# ### 110.再次读取数据1并显示所有的列

# %% [markdown]
# ### 111.查找secondType与thirdType值相等的行号

# %% [markdown]
# ### 112.查找薪资大于平均薪资的第三个数据

# %% [markdown]
# ### 113.将上一题数据的salary列开根号

# %% [markdown]
# ### 114.将上一题数据的linestaion列按_拆分

# %% [markdown]
# ### 115.查看上一题数据中一共有多少列

# %% [markdown]
# ### 116.提取industryField列以'数据'开头的行

# %% [markdown]
# ### 117.按列制作数据透视表

# %% [markdown]
# ### 118.同时对salary、score两列进行计算

# %% [markdown]
# ### 119.对salary求平均，对score列求和

# %% [markdown]
# ### 120.计算并提取平均薪资最高的区
