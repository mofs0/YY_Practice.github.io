# %%
import requests

# %% [markdown]
# 请求的构成:
# 请求头
# 请求行
# 请求体

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0'

}

# %%
url = 'https://www.xinpianchang.com/discover/article?from=navigator'

# %%
#网络请求中的响应状态码
#-2XX -成功系列
#-3XX -重定向
#-4XX -客户端错误
#-5XX -服务器内部错误
response = requests.request('GET',url,headers=headers)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html><html lang="en"><head><meta name="renderer" content="webkit"/><link rel="shortcut icon" href="/favicon.ico" type="image/x-icon"/><meta charSet="utf-8"/><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0"/><meta name="description" content="Passport of New Studios Media Social Networks" class="jsx-2350755402"/><title>Log In - New Studios Media</title><link rel="preload" href="https://static2.xpccdn.com/_next/static/images/flags-d47f95db62c588818ee472d7895eaedf.png" as="image" class="jsx-512335254"/><meta name="next-head-count" content="5"/><link rel="preload" href="https://static2.xpccdn.com/_next/static/css/commons.8447e57e.chunk.css" as="style"/><link rel="stylesheet" href="https://static2.xpccdn.com/_next/static/css/commons.8447e57e.chunk.css"/><link rel="preload" href="https://static2.xpccdn.com/_next/static/css/styles.5ad78e44.chunk.css" as="style"/><link rel="stylesheet" href="https://static2.xpccdn.com/_next/static/css/styles.5ad78e44.chunk.css"/><link rel="preload" href="https://static2.xpccdn.com/_next/static/production-1.1.3-184/pages/login.js" as="script"/><link rel="preload" href="https://static2.xpccdn.com/_next/static/production-1.1.3-184/pages/_app.js" as="script"/><link rel="preload" href="https://static2.xpccdn.com/_next/static/runtime/webpack-95effd35247a23f62f64.js" as="script"/><link rel="preload" href="https://static2.xpccdn.com/_next/static/chunks/commons.9aab50590b1227193bf6.js" as="script"/><link rel="preload" href="https://static2.xpccdn.com/_next/static/chunks/styles.432ee885291224e70720.js" as="script"/><link rel="preload" href="https://static2.xpccdn.com/_next/static/runtime/main-9883edf1257f1eed9251.js" as="script"/><style id="__jsx-512335254">.flag{display:inline-block;background-image:url(https://static2.xpccdn.com/_next/static/images/flags-d47f95db62c588818ee472d7895eaedf.png);background-repeat:no-repeat;width:32px;height:32px;-webkit-transform:scale(0.5);-ms-transform:scale(0.5);transform:scale(0.5);vertical-align:middle;position:relative;top:-1.5px;margin-left:-8px;}</style><style id="__jsx-2944639022">.transition>*{top:0;left:0;width:100%;position:absolute;}.transition>*:last-child{position:static;}</style><style id="__jsx-2350755402">.ant-layout.user-layout{background:transparent;}svg.logo path{fill:white;}.user-layout>.ant-layout-content{margin:0 auto;padding:0;}body .fixed-background{background-image:url(https://static2.xpccdn.com/_next/static/images/splash-52e44096f61ccb97be15902346a4dfb9.jpg);}.ant-layout-footer small{text-shadow:0 0 1px #0000003d;}.page-transition-enter,.page-transition-appear{-webkit-transform:translateX(100%);-ms-transform:translateX(100%);transform:translateX(100%);-webkit-transition:none;transition:none;}.return .page-transition-enter,.return .page-transition-appear{-webkit-transform:translateX(-100%);-ms-transform:translateX(-100%);transform:translateX(-100%);}.page-transition-enter-active,.page-transition-appear-active{-webkit-transition:all 300ms cubic-bezier(0.25,0,0,1);transition:all 300ms cubic-bezier(0.25,0,0,1);-webkit-transform:translateX(0%) !important;-ms-transform:translateX(0%) !important;transform:translateX(0%) !important;}.page-transition-exit{-webkit-transform:translateX(0);-ms-transform:translateX(0);transform:translateX(0);-webkit-transition:none;transition:none;}.page-transition-exit-active{-webkit-transition:all 300ms cubic-bezier(0.25,0,0,1);transition:all 300ms cubic-bezier(0.25,0,0,1);-webkit-transform:translateX(-100%);-ms-transform:translateX(-100%);transform:translateX(-100%);}.return .page-transition-exit-active{-webkit-transition:all 300ms cubic-bezier(0.25,0,0,1);transition:all 300ms cubic-bezier(0.25,0,0,1);-webkit-transform:translateX(100%);-ms-transform:translateX(100%);transform:translateX(100%);}.ant-card{border-radius:0 4px 4px 0;}</style></head><body class="body___1wZo-"><div class="fixed-background"></div><div id="__next"><section class="user-layout ant-layout"><header ...

# %%
#静态数据给好url和请求头就可以了
#动态数据需要自己分析网络
