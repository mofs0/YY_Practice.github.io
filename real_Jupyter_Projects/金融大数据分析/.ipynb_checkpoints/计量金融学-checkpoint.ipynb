# %% [markdown]
# # 欧式看涨期权的估值

# %% [markdown]
# ##  蒙特卡洛模拟

# %%
import math
import numpy as np
s0 = 100
K = 105
T = 1.0
r = 0.05
sigma = 0.2
I = 100000

# %%
z = np.random.standard_normal(I)

# %%
ST =s0 * np.exp((r-0.5 * sigma ** 2) * T + sigma * math.sqrt(T) * z)
hT = np.maximum(ST - K , 0)
C0 = math.exp(-r * T) * np.mean(hT)
print('欧式期权的价值 %5.3f' % C0)
# Out:
# 欧式期权的价值 8.102
