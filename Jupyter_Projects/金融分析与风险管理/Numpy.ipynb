# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.26.4'

# %%
weight = np.array([0.15,0.2,0.25,0.4])
type(weight)
# Out:
# numpy.ndarray

# %%
weight.shape
# Out:
# (4,)

# %%
stock_return = np.array([[0.00371,0.021066,-0.004854,0.006098,-0.00606],[-0.001838,0.001842,-0.016544,-0.003738,0.003752],[-0.003087,-0.00344,-0.033391,0.007123,0.004597],[-0.024112,0.011704,-0.029563,-0.01475,0.016129]]
                       )

# %%
stock_return.shape
# Out:
# (4, 5)

# %%
weight_list = [0.15,0.2,0.25,0.4]
weight_array = np.array(weight_list)
