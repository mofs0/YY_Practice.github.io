# %%
#转换器与预估器

# %%
#转换器
#标准化 (x-mean)/std
#fit()计算每一列的平均值与标准差
#transform() (x-mean)/std

# %%
#估计器
#1实例化一个estimator
#estimator.fit(x_train,y_train) 计算并生成模型
#3.评估模型
#比对真实值与预测值 y_predict = estimator.predict(x_test) y_test == y_predict
#直接计算准确率 accurary = estimator.score(x_test,y_test)
