# %%
import pandas as pd

# %%
starkbucks = pd.read_csv('./directory.csv')

# %%
count = starkbucks.groupby(['Country']).count()
count
# Out:
#          Brand  Store Number  Store Name  Ownership Type  Street Address  \
# Country
# AD           1             1           1               1               1
# AE         144           144         144             144             144
# AR         108           108         108             108             108
# AT          18            18          18              18              18
# AU          22            22          22              22              22
# ...        ...           ...         ...             ...             ...
# TT           3             3           3               3               3
# TW         394           394         394             394             394
# US       13608         13608       13608           13608           13608
# VN          25            25          25              25              25
# ZA           3             3           3               3               3
#
#           City  State/Province  Postcode  Phone Number  Timezone  Longitude  \
# ...

# %%
count['Brand'].plot(kind='bar',figsize=(20,8))
# Out:
# <Axes: xlabel='Country'>

# %%
starkbucks.groupby(['Country','State/Province']).count()
# Out:
#                         Brand  Store Number  Store Name  Ownership Type  \
# Country State/Province
# AD      7                   1             1           1               1
# AE      AJ                  2             2           2               2
#         AZ                 48            48          48              48
#         DU                 82            82          82              82
#         FU                  2             2           2               2
# ...                       ...           ...         ...             ...
# US      WV                 25            25          25              25
#         WY                 23            23          23              23
# VN      HN                  6             6           6               6
#         SG                 19            19          19              19
# ZA      GT                  3             3           3               3
#
#                         Street Address  City  Postcode  Phone Number  \
# ...
