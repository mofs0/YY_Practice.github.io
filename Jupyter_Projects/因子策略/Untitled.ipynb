# %%
import pandas as pd
import jqdata
df = get_price('601318.XSHG')
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import jqdata
#       3 df = get_price('601318.XSHG')
#       4 df
#
# ModuleNotFoundError: No module named 'jqdata'
