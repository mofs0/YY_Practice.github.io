# %% [markdown]
# 菜鸟

# %%
a = [1,2,3,4]
b = 'abcdef'
print(a[::-1])
print(b[::-1])
# Out:
# [4, 3, 2, 1]
# fedcba

# %%
print('hello %s!'% ('Tom'))
# Out:
# hello Tom!

# %% [markdown]
# 老鸟

# %%
a = [1,2,3,4]
b = 'abcdef'
print(list(reversed(a)))
print(list(reversed(b)))
# Out:
# [4, 3, 2, 1]
# ['f', 'e', 'd', 'c', 'b', 'a']

# %%
print('Hello %(name)s!' % {'name':'Tom'})
# Out:
# Hello Tom!
